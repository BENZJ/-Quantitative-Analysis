# %%
% cd /content/drive/MyDrive/股市分析/RNN_test/
! pip install backtrader
# Out:
# /content/drive/.shortcut-targets-by-id/142/股市分析/RNN_test
# ...
#      |████████████████████████████████| 419kB 15.9MB/s
# ...

# %%
# 采用学习率0.01训练可以成功训练
! python3 train.py --useGPU True --epochs 100000 --lr 0.01 --saveepochs 100 --corpusFile ../data/sh-1-34095.csv --continue_train True
# Out:
# 第0 epoch，保存模型
# 17.020503908395767
# 第100 epoch，保存模型
# 5.094203799962997
# 第200 epoch，保存模型
# 5.735843971371651
# 第300 epoch，保存模型
# 5.687751933932304
# 第400 epoch，保存模型
# 10.674106299877167
# 第500 epoch，保存模型
# 5.250971078872681
# 第600 epoch，保存模型
# 3.8895574137568474
# 第700 epoch，保存模型
# 5.729452699422836
# 第800 epoch，保存模型
# 3.504428490996361
# 第900 epoch，保存模型
# 3.2375865429639816
# 第1000 epoch，保存模型
# 3.317980222404003
# 第1100 epoch，保存模型
# 3.4288727790117264
# 第1200 epoch，保存模型
# 3.853075221180916
# 第1300 epoch，保存模型
# 5.200741350650787
# 第1400 epoch，保存模型
# 4.564233332872391
# 第1500 epoch，保存模型
# 5.573374822735786
# 第1600 epoch，保存模型
# 5.8718166798353195
# 第1700 epoch，保存模型
# 11.183085680007935
# 第1800 epoch，保存模型
# 11.340085506439209
# 第1900 epoch，保存模型
# 7.069183364510536
# 第2000 epoch，保存模型
# 5.561299368739128
# 第2100 epoch，保存模型
# 5.2150024473667145
# 第2200 epoch，保存模型
# 5.5431452840566635
# 第2300 epoch，保存模型
# 4.8315461948513985
# 第2400 epoch，保存模型
# 5.51190147548914
# 第2500 epoch，保存模型
# ...
