# %%
% cd /content/drive/MyDrive/股市分析/RNN_test/
! pip install backtrader
# Out:
# /content/drive/.shortcut-targets-by-id/142/股市分析/RNN_test
# ...

# %%
# 运行双参数输出，结果很差。
! python3 train.py --useGPU True --epochs 100000 --lr 0.001 --saveepochs 2
# Out:
# 第0 epoch，保存模型
# 16318.781848967075
# 第2 epoch，保存模型
# 16312.01913768053
# 第4 epoch，保存模型
# 16310.793131291866
# 第6 epoch，保存模型
# 16309.8140360713
# 第8 epoch，保存模型
# 16308.787706315517
# 第10 epoch，保存模型
# 16307.0528023839
# 第12 epoch，保存模型
# 16305.114808559418
# 第14 epoch，保存模型
# 16303.243884027004
# 第16 epoch，保存模型
# 16302.508791923523
# 第18 epoch，保存模型
# 16301.4398162961
# 第20 epoch，保存模型
# 16301.085082828999
# 第22 epoch，保存模型
# 16300.432495713234
# 第24 epoch，保存模型
# 16299.265500426292
# 第26 epoch，保存模型
# 16298.768300294876
# 第28 epoch，保存模型
# 16297.518964707851
# 第30 epoch，保存模型
# 16296.804839491844
# 第32 epoch，保存模型
# 16295.171662032604
# 第34 epoch，保存模型
# 16294.890287041664
# 第36 epoch，保存模型
# 16292.732505202293
# 第38 epoch，保存模型
# 16292.385927438736
# 第40 epoch，保存模型
# 16290.58472698927
# 第42 epoch，保存模型
# 16289.618239581585
# 第44 epoch，保存模型
# 16288.988219976425
# 第46 epoch，保存模型
# 16287.116322219372
